# %% [markdown]
# <a href="https://colab.research.google.com/github/inaafina/FinalThesis/blob/main/EDA_BPJS_1516.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 01Kepesertaan

# %% [markdown]
# ## Open file

# %%
#connecting to the drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Read the CSV file with the specified delimiter
df_1 = pd.read_csv('/content/drive/MyDrive/**SEMESTER VII/4. Proposal/Code Related/BPJS 2015-2016/01Kepesertaan.csv', delimiter='|')

# Display the first few rows of the DataFrame
df_1.head()
# Out:
#       PSTV01     PSTV02     PSTV03   PSTV04     PSTV05             PSTV06  \
# 0   40691029   40691029  29sep1967  Peserta  Laki-laki              KAWIN
# 1  152493455    3033115  01jun1999     Anak  Perempuan  TIDAK TERDEFENISI
# 2  186237297  186237297  23jan1979  Peserta  Laki-laki              KAWIN
# 3   41208383  115992342  17sep2007     Anak  Laki-laki        BELUM KAWIN
# 4   91535814   89186582  01oct2007     Anak  Laki-laki  TIDAK TERDEFENISI
#
#       PSTV07    PSTV08                    PSTV09             PSTV10   PSTV11  \
# 0  Kelas III      PBPU           SULAWESI TENGAH          KAB. POSO  Pem Kab
# 1  Kelas III  PBI APBN                 GORONTALO  KAB. BONE BOLANGO  Pem Kab
# 2  Kelas III      PBPU                JAWA TIMUR     KAB. MOJOKERTO  Pem Kab
# 3    Kelas I       PPU  NANGGROE ACEH DARUSSALAM    KOTA BANDA ACEH  Pem Kab
# 4  Kelas III  PBI APBN               JAWA TENGAH      KAB. MAGELANG  Pem Kab
#
# ...

# %%
df_1.nunique()
# Out:
# PSTV01    1697452
# PSTV02     586969
# PSTV03      33456
# PSTV04          5
# PSTV05          3
# PSTV06          4
# PSTV07          4
# PSTV08          5
# PSTV09         35
# PSTV10        513
# PSTV11          9
# PSTV12          3
# PSTV13         34
# PSTV14        514
# PSTV15       6778
# dtype: int64

# %%
df_1['PSTV05'].unique()
# Out:
# array(['Laki-laki', 'Perempuan', 'Tidak terdefinisi'], dtype=object)

# %%
(df_1['PSTV05'] == 'Tidak terdefinisi').sum()

#will drop the non defined
# Out:
# 2

# %%
df_1.shape
# Out:
# (1697452, 15)

# %% [markdown]
# ## Data cleansing

# %%
#checking for null values
df_1.isnull().sum()
# Out:
# PSTV01       0
# PSTV02       0
# PSTV03       0
# PSTV04       0
# PSTV05       0
# PSTV06    5373
# PSTV07       0
# PSTV08       0
# PSTV09     190
# PSTV10     190
# PSTV11    1389
# PSTV12       0
# PSTV13       2
# PSTV14       2
# PSTV15       0
# dtype: int64

# %% [markdown]
# # 02KunjunganFKTP

# %% [markdown]
# ## Open File

# %%
# Read the CSV file with the specified delimiter
df_2 = pd.read_csv('/content/drive/MyDrive/**SEMESTER VII/4. Proposal/Code Related/BPJS 2015-2016/02KunjunganFKTP.csv', delimiter='|')

# Display the first few rows of the DataFrame
df_2.head()
# Out:
#    PSTV01             FKP02      FKP03      FKP04        FKP05  \
# 0     218  214050216Y000058  24feb2016  24feb2016      LAMPUNG
# 1     218  214050315Y000005  02mar2015  02mar2015      LAMPUNG
# 2     340  115641115Y001030  20nov2015  20nov2015  JAWA TENGAH
# 3     340   78800516Y000637  26may2016  26may2016  JAWA TENGAH
# 4     340  115641015Y000805  15oct2015  15oct2015  JAWA TENGAH
#
#                 FKP06   FKP07           FKP08                      FKP09  \
# 0  KAB. LAMPUNG BARAT  Swasta     Dokter Umum  Dokter Praktek Perorangan
# 1  KAB. LAMPUNG BARAT  Swasta     Dokter Umum  Dokter Praktek Perorangan
# 2      KAB. SUKOHARJO  Swasta  Klinik Pratama      Klinik Non Rawat Inap
# 3      KAB. SUKOHARJO  Swasta  Klinik Pratama      Klinik Non Rawat Inap
# 4      KAB. SUKOHARJO  Swasta  Klinik Pratama      Klinik Non Rawat Inap
#
#                          FKP10  ...                                     FKP15  \
# ...

# %%
df_2.nunique()
# Out:
# PSTV01     465017
# FKP02     1733757
# FKP03         731
# FKP04         766
# FKP05          34
# FKP06         510
# FKP07           9
# FKP08           6
# FKP09          11
# FKP10           3
# FKP11          13
# FKP12           5
# FKP13           7
# FKP14        8684
# FKP15        8641
# FKP16          35
# FKP17         460
# FKP18           9
# FKP19           8
# FKP20          38
# FKP21          82
# FKP22           2
# FKP23        1818
# PSTV15       3556
# dtype: int64

# %%
#checking for null values
df_2.isnull().sum()
# Out:
# PSTV01          0
# FKP02           0
# FKP03           0
# FKP04           2
# FKP05           0
# FKP06           0
# FKP07          23
# FKP08           0
# FKP09           0
# FKP10           0
# FKP11           0
# FKP12         772
# FKP13           2
# FKP14           2
# FKP15       21004
# FKP16     1572314
# FKP17     1572314
# FKP18     1572386
# FKP19     1572316
# FKP20     1572713
# FKP21     1572324
# FKP22           0
# FKP23        4399
# PSTV15          0
# dtype: int64
